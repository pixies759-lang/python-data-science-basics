# %%
import pandas as pd
import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 import pandas as pd
#       2 import numpy as np
#
# ModuleNotFoundError: No module named 'pandas'

# %%
import sys
sys.executable
# !python -m pip install pandas numpy
# Out:
# ...
#    ---------------------------------------- 0.0/11.0 MB ? eta -:--:--
#    ------- -------------------------------- 2.1/11.0 MB 10.8 MB/s eta 0:00:01
#    ------------- -------------------------- 3.7/11.0 MB 9.6 MB/s eta 0:00:01
#    -------------------- ------------------- 5.5/11.0 MB 9.2 MB/s eta 0:00:01
#    ------------------------- -------------- 7.1/11.0 MB 8.7 MB/s eta 0:00:01
#    ------------------------------- -------- 8.7/11.0 MB 8.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.4/11.0 MB 7.9 MB/s eta 0:00:01
#    ---------------------------------------  10.7/11.0 MB 7.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.0/11.0 MB 7.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/12.3 MB ? eta -:--:--
#    ----- ---------------------------------- 1.8/12.3 MB 8.7 MB/s eta 0:00:02
#    ------------ --------------------------- 3.9/12.3 MB 9.2 MB/s eta 0:00:01
# ...

# %%
import pandas as pd
import numpy as np

# %%
data = {
    "nombre": ["Octavio", "Berenice", "Stevie", "Erick", "Kevin"],
    "edad": [35, 23, 48, 23, 22],
    "ingresos": [20000, 15000, 60000, 15000, 15000]
}

df = pd.DataFrame(data)
df
# Out:
#      nombre  edad  ingresos
# 0   Octavio    35     20000
# 1  Berenice    23     15000
# 2    Stevie    48     60000
# 3     Erick    23     15000
# 4     Kevin    22     15000

# %%
df.head()
# Out:
#      nombre  edad  ingresos
# 0   Octavio    35     20000
# 1  Berenice    23     15000
# 2    Stevie    48     60000
# 3     Erick    23     15000
# 4     Kevin    22     15000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   nombre    5 non-null      object
#  1   edad      5 non-null      int64
#  2   ingresos  5 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 252.0+ bytes

# %%
df.describe
# Out:
# <bound method NDFrame.describe of      nombre  edad  ingresos
# 0   Octavio    35     20000
# 1  Berenice    23     15000
# 2    Stevie    48     60000
# 3     Erick    23     15000
# 4     Kevin    22     15000>

# %%
df["edad"]
df[["nombre","ingresos"]]
df[df["ingresos"]> 15000]
# Out:
#     nombre  edad  ingresos
# 0  Octavio    35     20000
# 2   Stevie    48     60000

# %%
df["ingresos anuales"]=df["ingresos"]*12
df
# Out:
#      nombre  edad  ingresos  ingresos anuales
# 0   Octavio    35     20000            240000
# 1  Berenice    23     15000            180000
# 2    Stevie    48     60000            720000
# 3     Erick    23     15000            180000
# 4     Kevin    22     15000            180000

# %%
def categoria (x):
    if x>15000:
        return "Alto"
    elif x==15000:
        return "Medio"
    else:
        return "Bajo"
df["Categoria_ingresos"]= df["ingresos"].apply(categoria)
df
# Out:
#      nombre  edad  ingresos  ingresos anuales Categoria_ingresos
# 0   Octavio    35     20000            240000               Alto
# 1  Berenice    23     15000            180000              Medio
# 2    Stevie    48     60000            720000               Alto
# 3     Erick    23     15000            180000              Medio
# 4     Kevin    22     15000            180000              Medio

# %%
df[df["Categoria_ingresos"]== "Alto"]
# Out:
#     nombre  edad  ingresos  ingresos anuales Categoria_ingresos
# 0  Octavio    35     20000            240000               Alto
# 2   Stevie    48     60000            720000               Alto

# %%
def solotu (x):
    if x==20000:
        return "Alto"
    else:
        return"Nada"
df["Solo_tu"]=df["ingresos"].apply(solotu)
df
# Out:
#      nombre  edad  ingresos  ingresos anuales Categoria_ingresos Solo_tu
# 0   Octavio    35     20000            240000               Alto    Alto
# 1  Berenice    23     15000            180000              Medio    Nada
# 2    Stevie    48     60000            720000               Alto    Nada
# 3     Erick    23     15000            180000              Medio    Nada
# 4     Kevin    22     15000            180000              Medio    Nada

# %%
df[df["Solo_tu"]=="Alto"]
# Out:
#     nombre  edad  ingresos  ingresos anuales Categoria_ingresos Solo_tu
# 0  Octavio    35     20000            240000               Alto    Alto
